# %%
require './bootstrap.rb'
page = use_selenium_session()
# Out:
# #<Capybara::Session>

# %%
page.visit('https://automationintesting.online/')
take_screenshot(page)
# Out:
# "<img src='data:image/png;base64,...' />"
# #<CZTop::Socket::PUB:0x7fa604906420 last_endpoint="tcp://127.0.0.1:49894">
