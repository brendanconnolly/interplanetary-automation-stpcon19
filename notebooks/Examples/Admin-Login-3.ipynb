# %% [markdown]
# # Starting Automating Login - Using Page Models

# %%
require './bootstrap.rb'

page = use_selenium_session()
# Out:
# #<Capybara::Session>

# %% [markdown]
# ## Login
# Setting variables for user

# %%
admin_username='admin'
admin_password='password'
# Out:
# "password"

# %%
page.visit('https://automationintesting.online/#/admin')

# %% [markdown]
# ### Login With Credentials

# %%
admin_page=AdminPage.new(page)
admin_page.login(admin_username,admin_password)
take_screenshot(page)
# Out:
# "<img src='data:image/png;base64,...' />"
# #<CZTop::Socket::PUB:0x7ffed9fa15e0 last_endpoint="tcp://127.0.0.1:63812">

# %% [markdown]
# ### Go Forth and Test

# %% [markdown]
# ### Close out

# %%
take_screenshot(page)
page.driver.quit
# Out:
# "<img src='data:image/png;base64,...' />"
